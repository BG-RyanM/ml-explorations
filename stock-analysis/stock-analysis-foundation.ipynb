# %% [markdown]
# # Stock Analysis Experiments
#
# ## Setup
#
# Install yfinance
# ```
# $ conda install -c conda-forge yfinance
# ```

# %%
import matplotlib.pyplot as plt

from core.ticker import Ticker, TickerManager
from core.chart import Chart
from core.indicator import Indicator, SMAIndicator, EMAIndicator, LongEntryIndicator
from ui.ui_matplotlib import MPLHelper

# %% [markdown]
# ## Load Stock Price Data
#
# The `Ticker` class pulls price/volume data from the web via the yfinance package and saves it to disk for faster loading in the future.
#
# The following cell demonstrates the form this data takes.

# %%
ticker_manager = TickerManager()
await ticker_manager.load(["GOOG"])

goog_ticker = ticker_manager.get_ticker("GOOG")
goog_ticker.print_info()
goog_chart = Chart(goog_ticker)

todays_date = goog_ticker.get_date(as_str=True)
three_days_ago = goog_ticker.get_date(days_offset=-3, as_str=True)
print(f"Today is {todays_date}, three days ago was {three_days_ago}")

goog_df = goog_ticker.dataframe
print(f"Most recent close on {goog_df.index[-1]} is {goog_df.iloc[-1].Close}")

print("size of GOOG DF", goog_chart.num_entries)
# Out:
# INFO:core.ticker:got GOOG from pickle
# INFO:core.ticker:now scraping, start date = 2023-5-20, end date = 2025-3-22
# INFO:core.ticker:got GOOG from scraping, start date = 2023-5-20, end date = 2025-3-22
# =================
# Symbol is: GOOG
# First five entries:
# --------
#                                 Open       High        Low      Close  \
# Date
# 2013-05-22 00:00:00-04:00  22.479740  22.647860  22.089205  22.152468
# 2013-05-23 00:00:00-04:00  21.843126  22.165916  21.768408  21.987335
# 2013-05-24 00:00:00-04:00  21.799789  21.888456  21.693935  21.751471
# 2013-05-28 00:00:00-04:00  22.005020  22.220213  21.927809  21.949478
# 2013-05-29 00:00:00-04:00  21.810997  21.867785  21.526564  21.626688
#
#                               Volume  Dividends  Stock Splits
# Date
# 2013-05-22 00:00:00-04:00  102807910        0.0           0.0
# 2013-05-23 00:00:00-04:00   91345105        0.0           0.0
# 2013-05-24 00:00:00-04:00   92216359        0.0           0.0
# 2013-05-28 00:00:00-04:00   90638467        0.0           0.0
# 2013-05-29 00:00:00-04:00   80837869        0.0           0.0
# Last five entries:
# --------
#                                  Open        High         Low       Close  \
# Date
# 2025-03-17 00:00:00-04:00  167.324997  168.460007  165.809998  166.570007
# 2025-03-18 00:00:00-04:00  165.960007  166.440002  158.800003  162.669998
# 2025-03-19 00:00:00-04:00  163.914993  168.132996  163.050003  166.279999
# 2025-03-20 00:00:00-04:00  163.824997  167.029999  163.139999  165.050003
# 2025-03-21 00:00:00-04:00  163.380005  166.470001  163.029999  166.250000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-03-17 00:00:00-04:00  17839100        0.0           0.0
# 2025-03-18 00:00:00-04:00  24616800        0.0           0.0
# 2025-03-19 00:00:00-04:00  24955700        0.0           0.0
# 2025-03-20 00:00:00-04:00  19981500        0.0           0.0
# 2025-03-21 00:00:00-04:00  29849000        0.0           0.0
# Most recent date breaks:
# --------
# 2025-03-16
# 2025-03-15
# 2025-03-09
# Today is 2025-03-22, three days ago was 2025-03-19
# Most recent close on 2025-03-21 00:00:00-04:00 is 166.25
# size of GOOG DF 2977

# %%
# Temporary cell
await ticker_manager.load(["SPY"])

spy_ticker = ticker_manager.get_ticker("SPY")
spy_ticker.print_info()
spy_chart = Chart(spy_ticker)
indicator_sma_30 = SMAIndicator((30,))
spy_chart.add_indicator(indicator_sma_30)

print("num entries for SPY are", spy_chart.num_entries)
spy_df = spy_chart.dataframe
print("SMA-30 value is", spy_df.iloc[30]["SMA-30"])
# Out:
# INFO:core.ticker:got SPY from pickle
# INFO:core.ticker:now scraping, start date = 2023-5-20, end date = 2025-3-22
# INFO:core.ticker:got SPY from scraping, start date = 2023-5-20, end date = 2025-3-22
# =================
# Symbol is: SPY
# First five entries:
# --------
#                                  Open        High         Low       Close  \
# Date
# 2013-05-23 00:00:00-04:00  136.426612  137.880965  136.243778  137.498672
# 2013-05-24 00:00:00-04:00  136.684208  137.440474  136.276984  137.382294
# 2013-05-28 00:00:00-04:00  138.819992  139.434980  137.797794  138.205017
# 2013-05-29 00:00:00-04:00  137.473674  137.789480  136.576129  137.307465
# 2013-05-30 00:00:00-04:00  137.415549  138.446053  137.307507  137.814453
#
#                               Volume  Dividends  Stock Splits  Capital Gains
# Date
# 2013-05-23 00:00:00-04:00  211064400        0.0           0.0            0.0
# 2013-05-24 00:00:00-04:00  151573900        0.0           0.0            0.0
# 2013-05-28 00:00:00-04:00  143679800        0.0           0.0            0.0
# 2013-05-29 00:00:00-04:00  160363400        0.0           0.0            0.0
# 2013-05-30 00:00:00-04:00  107793800        0.0           0.0            0.0
# Last five entries:
# --------
#                                  Open        High         Low       Close  \
# Date
# 2025-03-17 00:00:00-04:00  561.102066  568.001355  560.663383  565.449036
# 2025-03-18 00:00:00-04:00  563.106034  563.325406  557.383259  559.337402
# 2025-03-19 00:00:00-04:00  561.141986  569.237628  559.945573  565.429077
# 2025-03-20 00:00:00-04:00  561.640511  568.858788  560.912659  563.794006
# 2025-03-21 00:00:00-04:00  559.280029  564.890015  558.030029  563.979980
#
#                              Volume  Dividends  Stock Splits  Capital Gains
# Date
# 2025-03-17 00:00:00-04:00  49008700      0.000           0.0            0.0
# 2025-03-18 00:00:00-04:00  66041400      0.000           0.0            0.0
# 2025-03-19 00:00:00-04:00  66556000      0.000           0.0            0.0
# 2025-03-20 00:00:00-04:00  62958200      0.000           0.0            0.0
# 2025-03-21 00:00:00-04:00  83666800      1.696           0.0            0.0
# Most recent date breaks:
# --------
# 2025-03-16
# 2025-03-15
# 2025-03-09
# num entries for SPY are 2976
# SMA-30 value is 135.4459437052409

# %% [markdown]
# ## Plot Chart Using matplotlib

# %%
my_chart = goog_chart
my_chart.add_ema(8)
my_chart.add_ema(11)
my_chart.add_sma(20)
my_chart.add_sma(50)
my_chart.add_sma(100)
my_chart.add_sma(200)
my_chart.add_long_entry(1.15, .95, 15) 
mpl_helper = MPLHelper(my_chart)
my_chart_start_idx = -700
my_chart_end_idx = -400
mpl_helper.show(my_chart_start_idx, my_chart_end_idx)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
mpl_helper = MPLHelper(my_chart)
mpl_helper.show_adjusted(my_chart_start_idx, my_chart_end_idx, 100)
